# %% [markdown]
# '''
# <br>
# @Author: Ayush Prajapati<br>
# @Date: 13-07-2024<br>
# @Last Modified by: Ayush Prajapati<br>
# @Last Modified time: 14-07-2024<br>
# @Title: Python Box Plot Programs using Seaborn library<br>
# <br>
# '''

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Q1
# **Write a program to draw box plot of life expectancy by continent for a data set given in a url**
# <br><br>
# Dataset: `https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv`

# %%
def main():
    # Loading the dataset using the link
    df = pd.read_csv('https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv')
    print(f"The columns of the dataset are: \n{df}\n\n")
    print(f"The columns of the dataset are: {df.columns}")
    print(f"\nThe box plot is\n\n")
    plt.figure(figsize=(13,7))
    
    # Create a box plot
    sns.boxplot(data=df, x='continent', y='lifeExp', hue='continent', palette="flare", legend=True)
    
    # Set plot labels and title
    plt.title('Continent vs Life Expectancy')
    plt.xlabel('Continent', labelpad=10)
    plt.ylabel('Life Expectancy', labelpad=12)
    plt.grid(axis='y', linestyle='-.', alpha=0.7)
    plt.legend(loc = "lower right")
    plt.show()
    

if __name__ == "__main__":
    main()
# Out:
# The columns of the dataset are:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]
#
#
# ...

# %% [markdown]
# ## Q2
# **Write a program to draw a box plot of day by tips for a dataset given in a url**
# <br><br>
# Dataset: `https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv `

# %%
def main():
    # Loading the dataset using the link
    df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')
    print(f"The columns of the dataset are: \n{df}\n\n")
    print(f"The columns of the dataset are: {df.columns}")
    print(f"\nThe box plot is\n\n")
    plt.figure(figsize=(13,7))
    
    # Create a box plot
    sns.boxplot(data=df, x='day', y='tip', hue='day', palette="deep", legend=True)
    
    # Set plot labels and title
    plt.title('Day vs Tips Received')
    plt.xlabel('Day', labelpad=10)
    plt.ylabel('Tips Received', labelpad=12)
    plt.grid(axis='y', linestyle='-.', alpha=0.7)
    plt.legend(loc = "upper right")
    plt.show()
    

if __name__ == "__main__":
    main()
# Out:
# The columns of the dataset are:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
#
#
# The columns of the dataset are: Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
#
# The box plot is
